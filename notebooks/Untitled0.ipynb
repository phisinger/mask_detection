# %%
# %cd drive/MyDrive/mask_detection
# Out:
# /content/drive/MyDrive/mask_detection

# %%
! git init

# %%
! git add models/ notebooks/ src/

# %%
! git config --global user.email "philipsinger@mail.de"
! git config --global user.name "Philip Singer"
